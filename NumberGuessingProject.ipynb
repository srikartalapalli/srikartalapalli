# %%
class a:
    def number_guessing():
        print("Welcome to Number Guessing Game!")
        print("Select one of the options below: ")
        print("1. Create an account")
        print("2. Login with existing username")
        print("3. Play the game")
        user_input = int(input("Enter the choice from the options above {1/2/3}: "))

        if user_input == 1:
            usernames = []
            new_user = input("Enter a username: ")
            if new_user in usernames:
                print("Username already taken!")
            else:
                usernames.append(new_user)

            passwords = []
            new_password = input("Enter a password: ")
            passwords.append(new_password)

            login_username = input("Enter your username: ")
            login_password = input("Enter your password: ")
            if login_username in usernames and login_password in passwords:
                print("Welcome to the number guessing game!")
            elif login_username in usernames and login_password not in passwords:
                print("Password is incorrect! Please try again!")
            else:
                print("Username does not exist! Please create an account and try again!")

        elif user_input == 2:

            login_username = input("Enter your username: ")
            login_password = input("Enter your password: ")
            if login_username in usernames and login_password in passwords:
                print("Welcome to the number guessing game!")
            elif login_username in usernames and login_password not in passwords:
                print("Password is incorrect! Please try again!")
            else:
                print("Username does not exist! Please create an account and try again!")

        elif user_input == 3:
            import random 

            points1 = []
            points2 = []
            total1 = sum(points1)
            total2 = sum(points2)
            print("Game started!!")

            print("Player 1's turn!!")
            p1_g1 = int(input("Enter your 1st guess: "))
            r1_g1 = random.randrange(1, 6)
            if p1_g1 == r1_g1:
                print("Guess correct! You get one point!")
                points1.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points1.append(-1)

            p1_g2 = int(input("Enter your 2nd guess: "))
            r1_g2 = random.randrange(1, 6)
            if p1_g2 == r1_g2:
                print("Guess correct! You get one point!")
                points1.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points1.append(-1)

            p1_g3 = int(input("Enter your 3rd guess: "))
            r1_g3 = random.randrange(1, 6)
            if p1_g3 == r1_g3:
                print("Guess correct! You get one point!")
                points1.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points1.append(-1)

            p1_g4 = int(input("Enter your 4th guess: "))
            r1_g4 = random.randrange(1, 6)
            if p1_g4 == r1_g4:
                print("Guess correct! You get one point!")
                points1.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points1.append(-1)

            p1_g5 = int(input("ENter your 5th guess: "))
            r1_g5 = random.randrange(1, 6)
            if p1_g5 == r1_g5:
                print("Guess correct! You get one point!")
                points1.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points1.append(-1)

            print("Player 1 got: ",total1)

            print("Player 2's turn!!")

            p2_g1 = int(input("Enter your 1st guess: "))
            r2_g1 = random.randrange(1, 6)
            if p2_g1 == r2_g1:
                print("Guess correct! You get one point!")
                points2.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points2.append(-1)

            p2_g2 = int(input("Enter your 2nd guess: "))
            r2_g2 = random.randrange(1, 6)
            if p2_g2 == r2_g2:
                print("Guess correct! You get one point!")
                points2.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points2.append(-1)

            p2_g3 = int(input("Enter your 3rd guess: "))
            r2_g3 = random.randrange(1, 6)
            if p2_g3 == r2_g3:
                print("Guess correct! You get one point!")
                points2.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points2.append(-1)

            p2_g4 = int(input("Enter your 4th guess: "))
            r2_g4 = random.randrange(1, 6)
            if p2_g4 == r2_g4:
                print("Guess correct! You get one point!")
                points2.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points2.append(-1)

            p2_g5 = int(input("ENter your 5th guess: "))
            r2_g5 = random.randrange(1, 6)
            if p2_g5 == r2_g5:
                print("Guess correct! You get one point!")
                points2.append(1)
            else:
                print("Wrong guess! Your get a negative point!")
                points2.append(-1)

            print("Player 2 got: ",total2)

            if total1 > total2:
                print("Player 1 is the winner!!")

            elif total1 < total2:
                print("Player 2 is the winner!!")

            else:
                print("It is a draw!!")
                
b = a
b.number_guessing()
